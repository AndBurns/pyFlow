# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/envs/modelflow/lib/python3.13/site-packages/werkzeug/serving.py:759, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     758 try:
# --> 759     self.server_bind()
#     760     self.server_activate()
#
# File ~/miniconda3/envs/modelflow/lib/python3.13/http/server.py:136, in HTTPServer.server_bind(self)
#     135 """Override server_bind to store the server name."""
# --> 136 socketserver.TCPServer.server_bind(self)
#     137 host, port = self.server_address[:2]
#
# File ~/miniconda3/envs/modelflow/lib/python3.13/socketserver.py:478, in TCPServer.server_bind(self)
#     477     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 478 self.socket.bind(self.server_address)
#     479 self.server_address = self.socket.getsockname()
#
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
# Cell In[15], line 25
#       6 app.layout = DashSpreadGrid(
#       7     data={
#       8     "John": {"name": "John", "age": 25, "score": 100, "registered": True, "team": "red"},
#    (...)     21   ],
#      22 )
#      24 if __name__ == "__main__":
# ---> 25   app.run()
#
# File ~/miniconda3/envs/modelflow/lib/python3.13/site-packages/dash/dash.py:2353, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors, **flask_run_options)
#    2350             extra_files.append(path)
#    2352 if jupyter_dash.active:
# -> 2353     jupyter_dash.run_app(
#    2354         self,
#    2355         mode=jupyter_mode,
#    2356         width=jupyter_width,
#    2357         height=jupyter_height,
#    2358         host=host,
#    2359         port=port,
#    2360         server_url=jupyter_server_url,
#    2361     )
#    2362 else:
#    2363     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~/miniconda3/envs/modelflow/lib/python3.13/site-packages/dash/_jupyter.py:336, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     332     pass
#     334 err_q = queue.Queue()
# --> 336 server = make_server(host, port, app.server, threaded=True, processes=0)
#     337 logging.getLogger("werkzeug").setLevel(logging.ERROR)
#     339 @retry(
#     340     stop_max_attempt_number=15,
#     341     wait_exponential_multiplier=100,
#     342     wait_exponential_max=1000,
#     343 )
#     344 def run():
#
# File ~/miniconda3/envs/modelflow/lib/python3.13/site-packages/werkzeug/serving.py:930, in make_server(host, port, app, threaded, processes, request_handler, passthrough_errors, ssl_context, fd)
#     927     raise ValueError("Cannot have a multi-thread and multi-process server.")
#     929 if threaded:
# --> 930     return ThreadedWSGIServer(
#     931         host, port, app, request_handler, passthrough_errors, ssl_context, fd=fd
#     932     )
#     934 if processes > 1:
#     935     return ForkingWSGIServer(
#     936         host,
#     937         port,
#    (...)    943         fd=fd,
#     944     )
#
# File ~/miniconda3/envs/modelflow/lib/python3.13/site-packages/werkzeug/serving.py:782, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     775         if sys.platform == "darwin" and port == 5000:
#     776             print(
#     777                 "On macOS, try disabling the 'AirPlay Receiver' service"
#     778                 " from System Preferences -> General -> AirDrop & Handoff.",
#     779                 file=sys.stderr,
#     780             )
# --> 782     sys.exit(1)
#     783 except BaseException:
#     784     self.server_close()
#
# SystemExit: 1

# %%
import dash
from dash_spread_grid import DashSpreadGrid

app = dash.Dash(__name__)

app.layout = DashSpreadGrid(
    data={
    "John": {"name": "John", "age": 25, "score": 100, "registered": True, "team": "red"},
    "Alice": {"name": "Alice", "age": 24, "score": 70, "registered": False, "team": "blue"},
    "Bob": {"name": "Bob", "age": 26, "score": 35, "registered": True, "team": "blue"},
    "Charlie": {"name": "Charlie", "age": 27, "score": 60, "registered": False, "team": "red"},
    "David": {"name": "David", "age": 18, "score": 60, "registered": True, "team": "red"},
    "Eve": {"name": "Eve", "age": 29, "score": 80, "registered": False, "team": "green"},
    "Frank": {"name": "Frank", "age": 30, "score": 50, "registered": True, "team": "blue"}
  },
  formatting=[
    {
      "column": [{"id": "name"}],
      "edit": True,
    }
  ],
)

if __name__ == "__main__":
  app.run()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
